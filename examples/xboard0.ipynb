# %%
# !pip install xboard==0.0.1
# Out:
# ...
#   Attempting uninstall: xboard
#     Found existing installation: xboard 0.0.0
#     Uninstalling xboard-0.0.0:
#       Successfully uninstalled xboard-0.0.0
# ...

# %%
liste_package = !pip list

for i in liste_package:
  if i.split(" ")[0] == "xboard":
    print("Installation du package xboard trouvée:")
    print(i)
# Out:
# Installation du package xboard trouvée:
# xboard                           0.0.1

# %%
import xboard

xboard.hello()
# Out:
# hello world!
